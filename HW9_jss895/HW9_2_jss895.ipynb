# %% [markdown]
# ## This notebook is designed to pratice with both geopandas and census data.  This is a simple spatial exploratory analysis of census data. The goal is to assess wheather the location of the [linkNYC](https://www.link.nyc/) access points is optimal to guarantee a more "democratic" access to the internet.
#
# ## THE CENSUS:
# make sure you do the assigned reading about the census. Census data are a national trasure! The census is a survey  designed to collect data on every person that lives in the USA every 10 years. The Census Bureau collects data, designes aggregation areas (the census blocks and tracts for example, which are designed for maximal homogeneity across all features). However, the Census Bureau does not only collect and aggregate data every 10 years, it also collects the America Community Survey every 5 years, and some more restricted survey on an annual bases. The 1 year survey data is what we will use: https://www.census.gov/services/index.html

# %% [markdown]
# # 1. PUMA : Public Use Microdata Area
# Census geographies that are not specific political entities (i.e. states, counties etc) are designed for homogeneity so that aggregating the data over the whole area will leat to an estimat (mean or median for example) with minimal variance. Among these geographies are the _census tracts_, _census blocks_, and _Public Use Microdata Areas (PUMAs)_. PUMAs are geographical areas designed to aggregate census data. Each PUMA contains at least 100,000 people. PUMAs do not overlap, and are contained within a single state.
#
# ## 1.1 download the NYC  Public Use Microdata Areas (PUMA) geometry fron the NYC Open Data API and read it in with geopandas
#
# https://data.cityofnewyork.us/Housing-Development/Public-Use-Microdata-Areas-PUMA-/cwiz-gcty/data
#
# download it as a shape file. When you download a shapefile you actually download a zipped folder which contains the shape file and other files that are necessary to read the shape file in. You can do that with the urllib library in python 3 with the function
#
#         urllib.request.urlretrieve(url, "file.gz")
#
# then unpack the data into your PUIdata directory, then read it in with geopandas, reading in the shape file with the function
#
#         geopandas.GeoDataFrame.from_file(filename)

# %% [markdown]
# PUMAs were first created for the 1990 Census. PUMAs are identified by a specific 4 numbers id. In the shapefile foung at data.cityofnewyork.us the id is named "puma" and it is in fact a 4 digits number. You can read it in as an integer (although of course it is a categorical variable inherently!). Often the PUMA id is found in conjunction with the 3 numbers state id, leading to a 7 numbers identification. The id for the State of NY is 036. See this link for more: https://www.census.gov/geo/reference/geoidentifiers.html

# %% [markdown]
# # Here we download the PUMA dataset and extract the shapefile

# %%
import urllib
import geopandas as gp
import zipfile


# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os

# %%
PUIdata = os.getenv("PUIDATA")
"The path to the PUIdata directory is " + PUIdata
# Out:
# 'The path to the PUIdata directory is /home/cusp/jss895/PUIdata'

# %%
#We download the shapefile to our current working directory (uncomment to download)
urllib.urlretrieve("https://data.cityofnewyork.us/api/geospatial/cwiz-gcty?method=export&format=Shapefile",PUIdata+"/puma.gz")
# Out:
# ('/home/cusp/jss895/PUIdata/puma.gz',
#  <httplib.HTTPMessage instance at 0x7f74896822d8>)

# %%
#we unzip
zip_ref = zipfile.ZipFile(PUIdata+"/puma.gz", 'r')
zip_ref.extractall(PUIdata)
zip_ref.close()

# %%
#reading the shape file into a data frame

#glob allows the use of wildcards
import glob
thefileiwant=glob.glob(PUIdata+"/geo_export_*.shp") #this creates a LIST object with the name of the shape files in my directory
                                           
print thefileiwant
df=gp.GeoDataFrame.from_file(thefileiwant[0])
# Out:
# ['/home/cusp/jss895/PUIdata/geo_export_1f8aa491-f06f-46ea-aa99-88ebc4dddbee.shp', '/home/cusp/jss895/PUIdata/geo_export_489d9d86-7a23-4d66-a890-274cddbc4eba.shp', '/home/cusp/jss895/PUIdata/geo_export_b295df28-56ea-49c5-be0f-b4e9e1bd9ca0.shp', '/home/cusp/jss895/PUIdata/geo_export_dc50ac43-f82e-445a-a84b-596c441911ee.shp']

# %% [markdown]
# # Here we read the Shapefile

# %%
df = gp.GeoDataFrame.from_file("geo_export_70d9b059-f572-4405-883c-797b41b74b9c.shp")

# %%
df.head()
# Out:
#    puma     shape_leng    shape_area  \
# 0  3701   53227.144376  9.792852e+07
# 1  3702  106050.008344  1.889860e+08
# 2  3703  304875.033427  2.670770e+08
# 3  3704   47970.900868  1.062129e+08
# 4  3705   68593.066759  1.224946e+08
#
#                                             geometry
# 0  POLYGON ((-73.89641133483133 40.90450452082026...
# 1  POLYGON ((-73.86477258283533 40.90201244187379...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.87045508990893 40.86663286876232...

# %%
df.crs
# Out:
# {'init': u'epsg:4326'}

# %% [markdown]
# ## 1.2  plot the PUMA NYC regions
#
# you can use the geopandas function plot.
# What is the appropriate plot to just show the shape of the PUMA regions? A choropleth could be ok, but it is better to just draw the contours of the region, since we do not want to highlight some regions over others by color choices.
#
# (Note: a while ago I wrote a quick function that plots choropleths and maps of NYC specifically putting legends and colorbars in the empty spaces taking advantage of the shape of the city and you are welcome to use it: https://github.com/fedhere/choroplethNYC. BUT YOU DO NOT HAVE TO)
#
# Your map should look someting like:

# %%
urllib.urlretrieve("https://raw.githubusercontent.com/fedhere/choroplethNYC/master/choroplethNYC.py","choroplethNYC.py")
# Out:
# ('choroplethNYC.py', <httplib.HTTPMessage instance at 0x7f74422348c0>)

# %%
# using the built in plot function as pumashp.plot(pumashp....)
# using a choroplethNYC function that FBB wrote
import choroplethNYC as cp

cp.choroplethNYC(df, column=None, color="white", edgecolor="black", lw=1);

# %% [markdown]
# ## Fig 1. This is a map of NYC devided by PUMA

# %% [markdown]
# # 2. American Fact Finder data on percentage of houses with broadband internet access
#
# Download the table of data from 2016 for NYC: you want to obtain data on broadband access (percentage of households with broadband access) at the PUMA (Public Use Microdata Area) geographical area level.
#
# This may be tricky. But familiarizing with Census and American Commjunity Survey data is super important for urban science. Here you should use the API, but you should also practice interacting with the website:
#
# You  should read the datta in thgouth the API but also download the data manually and compare the two datasets.

# %% [markdown]
# ## 2.1 Get data with American Fact Finder (AFF) API:
# you can request an API key, although I think it is not necessary for this search (but it is good to practice). Obtain a key and save it into a python file. DO NOT UPLOAD THE FILE CONTAINING THE API KEY TO GITHUB. Keep your API keys private.

# %% [markdown]
# If you need help with the API you can ask questions in this [Gitter channel](https://gitter.im/uscensusbureau/general) (I did myself to design this homework!)
# The internet subscription by household is data surveyd annually. You can find out what are the features that you can query through the API for the annually surveyed data at this url: https://api.census.gov/data/2016/acs/acs1/variables.json
#
# read it in as a jason file - you can do it with pandas (but it is slow). You can do it as I do below with the request package

# %%
#read in in the variables available. the info you need is in the 1year ACS data
import requests
import json

url = "https://api.census.gov/data/2016/acs/acs1/variables.json"
resp = requests.request('GET', url)
aff1y = json.loads(resp.text)

# %%
affkeys = np.array(list(aff1y['variables'].keys()))

# %% [markdown]
# We need two features: total number of households, and number of households with broadband access
#
# Broadband access is one of the B28002 keys. We will check the rows that start with "B28002"and have "Broadband" in the description.

# %%
affkeys
# Out:
# array([u'B17022_035MA', u'B25087_038MA', u'B24010E_007M', ...,
#        u'C01001I_005MA', u'B24122_437E', u'C08016_009M'],
#       dtype='<U15')

# %% [markdown]
# You need two features: **total number of households**, and **number of households with broadband access**
#
# Broadband access is one of the B28002 keys. However there are many of those! Each variable has several observations associated to it: B28002 is all internet access data (broadband, dial up, none, ...), and for each of those you have the estimate (count, mean, median, percentage...), the margin of errors, and annotations. Those are identified by an appendix that begins with "\_". Look carefully at the line of code below and its output. I am creating a list that contains the keys of the dictionary I created from the json file for all B28002 observations  (rows that start with "B28002") that include the word "Broadband" in the description.
#
# The syntax is a lost comprehension:
#
#         as = \[a for a in listOfAs\]
#
# is simply a compact way to write
#
#         as = \[\]
#         for a in listOfAs:
#             as.append(a)
#
# with an if statement tha selects broadband

# %% [markdown]
# # Here we extract variables of B28002 that contain "broadband"

# %%
[(k, aff1y['variables'][k]['label'])  for k in affkeys if k.startswith ("B28002") and 
 'Broadband' in aff1y['variables'][k]['label']]
# Out:
# [(u'B28002_008E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28002_008M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28002_004MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_008MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28002_004E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_004M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_007MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28002_007EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28002_004EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_008EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28002_007M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28002_007E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL')]

# %% [markdown]
# chose the appropriate variable and extract the relevant data: below I select the variable containing the number of household per PUMA. The "all" variable, which tells you what is the total number of units queried (households here) is generally stored in the \_001 variable (B28002_001 in this case). "E" stands for *estimate*. M stands for *margin of error*, EA *estimate annotations*, MA *margin of error annotations*. You want the estimate for this exercise.

# %%
#keyword for the number of households
keyNhouseholds = 'B28002_001E'
aff1y['variables'][keyNhouseholds]
# Out:
# {u'attributes': u'B28002_001M,B28002_001EA',
#  u'concept': u'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  u'group': u'B28002',
#  u'label': u'Estimate!!Total',
#  u'limit': 0,
#  u'predicateType': u'int',
#  u'validValues': []}

# %% [markdown]
# Similarly, choose the fractions of houses with any "With an Internet subscription!!Broadband of any type"

# %%
#keyword for the number of households with broarband access
keyNBB = "B28002_004E"
aff1y['variables'][keyNBB]
# Out:
# {u'attributes': u'B28002_004M,B28002_004EA',
#  u'concept': u'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  u'group': u'B28002',
#  u'label': u'Estimate!!Total!!With an Internet subscription!!Broadband of any type',
#  u'limit': 0,
#  u'predicateType': u'int',
#  u'validValues': []}

# %% [markdown]
# # Just for curiosity I wanted to see other type of internet connections

# %%
[(k, aff1y['variables'][k]['label'])  for k in affkeys if k.startswith != ("B28002") and 
 'Internet' in aff1y['variables'][k]['label']]
# Out:
# [(u'B28006_016MA',
#   u"Annotation of Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28004_016M',
#   u'Margin of Error!!Total!!$35,000 to $49,999!!With a broadband Internet subscription'),
#  (u'B28004_016E',
#   u'Estimate!!Total!!$35,000 to $49,999!!With a broadband Internet subscription'),
#  (u'B28009I_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_008M',
#   u'Margin of Error!!Total!!$10,000 to $19,999!!With a broadband Internet subscription'),
#  (u'B28002_002E', u'Estimate!!Total!!With an Internet subscription'),
#  (u'B28009C_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_003M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Dial-up alone'),
#  (u'B28006_017E',
#   u"Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28006_017M',
#   u"Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28004_015MA',
#   u'Annotation of Margin of Error!!Total!!$35,000 to $49,999!!With dial-up Internet subscription alone'),
#  (u'B28002_002MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription'),
#  (u'B28005_004E',
#   u'Estimate!!Total!!Under 18 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_004M',
#   u'Margin of Error!!Total!!Under 18 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_009MA',
#   u'Annotation of Margin of Error!!Total!!$10,000 to $19,999!!Without an Internet subscription'),
#  (u'B28004_007M',
#   u'Margin of Error!!Total!!$10,000 to $19,999!!With dial-up Internet subscription alone'),
#  (u'B28009F_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_021MA',
#   u'Annotation of Margin of Error!!Total!!$50,000 to $74,999!!Without an Internet subscription'),
#  (u'B28008_007MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!Without a cellular data plan'),
#  (u'B28009I_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28003_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_012EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_007MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!Without an Internet subscription'),
#  (u'B28009H_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009H_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_019E',
#   u'Estimate!!Total!!$50,000 to $74,999!!With dial-up Internet subscription alone'),
#  (u'B28011_006M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Other service'),
#  (u'B28011_006E',
#   u'Estimate!!Total!!With an Internet subscription!!Other service'),
#  (u'B28005_016MA',
#   u'Annotation of Margin of Error!!Total!!65 years and over!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009H_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_009EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28004_007E',
#   u'Estimate!!Total!!$10,000 to $19,999!!With dial-up Internet subscription alone'),
#  (u'B28004_016MA',
#   u'Annotation of Margin of Error!!Total!!$35,000 to $49,999!!With a broadband Internet subscription'),
#  (u'B28004_003E',
#   u'Estimate!!Total!!Less than $10,000!!With dial-up Internet subscription alone'),
#  (u'B28009D_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_008E',
#   u'Estimate!!Total!!$10,000 to $19,999!!With a broadband Internet subscription'),
#  (u'B28002_010EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Satellite Internet service!!Satellite Internet service with no other type of Internet subscription'),
#  (u'B28009E_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009E_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009D_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_006M',
#   u'Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_006E',
#   u'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_011MA',
#   u'Annotation of Margin of Error!!Total!!$20,000 to $34,999!!With dial-up Internet subscription alone'),
#  (u'B28007_017MA',
#   u'Annotation of Margin of Error!!Total!!Not in labor force!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_009E',
#   u'Estimate!!Total!!$10,000 to $19,999!!Without an Internet subscription'),
#  (u'B28004_005EA',
#   u'Annotation of Estimate!!Total!!Less than $10,000!!Without an Internet subscription'),
#  (u'B28002_009M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28002_012M',
#   u'Margin of Error!!Total!!Internet access without a subscription'),
#  (u'B28002_012E', u'Estimate!!Total!!Internet access without a subscription'),
#  (u'B28002_002M', u'Margin of Error!!Total!!With an Internet subscription'),
#  (u'B28007_011MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009G_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_008E', u'Estimate!!Total!!No Internet access'),
#  (u'B28011_008M', u'Margin of Error!!Total!!No Internet access'),
#  (u'B28005_004EA',
#   u'Annotation of Estimate!!Total!!Under 18 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28006_011E',
#   u"Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28006_011M',
#   u"Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28009C_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_003MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Dial-up alone'),
#  (u'B28003_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_006EA',
#   u'Annotation of Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!Without an Internet subscription'),
#  (u'B28011_007EA',
#   u'Annotation of Estimate!!Total!!Internet access without a subscription'),
#  (u'B28009B_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_024EA',
#   u'Annotation of Estimate!!Total!!$75,000 or more!!With a broadband Internet subscription'),
#  (u'B28009C_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28003_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28003_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28002_012MA',
#   u'Annotation of Margin of Error!!Total!!Internet access without a subscription'),
#  (u'B28009F_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009B_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28006_018MA',
#   u"Annotation of Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!Without an Internet subscription"),
#  (u'B28002_008E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28002_008M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28004_005MA',
#   u'Annotation of Margin of Error!!Total!!Less than $10,000!!Without an Internet subscription'),
#  (u'B28011_003E',
#   u'Estimate!!Total!!With an Internet subscription!!Dial-up alone'),
#  (u'B28011_004MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
#  (u'B28004_023MA',
#   u'Annotation of Margin of Error!!Total!!$75,000 or more!!With dial-up Internet subscription alone'),
#  (u'B28008_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription'),
#  (u'B28007_019MA',
#   u'Annotation of Margin of Error!!Total!!Not in labor force!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_011M',
#   u'Margin of Error!!Total!!$20,000 to $34,999!!With dial-up Internet subscription alone'),
#  (u'B28004_011E',
#   u'Estimate!!Total!!$20,000 to $34,999!!With dial-up Internet subscription alone'),
#  (u'B28005_012MA',
#   u'Annotation of Margin of Error!!Total!!18 to 64 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_009M',
#   u'Margin of Error!!Total!!$10,000 to $19,999!!Without an Internet subscription'),
#  (u'B28008_006M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!With a cellular data plan'),
#  (u'B28002_003E',
#   u'Estimate!!Total!!With an Internet subscription!!Dial-up with no other type of Internet subscription'),
#  (u'B28006_005MA',
#   u'Annotation of Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_016E',
#   u"Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28006_016M',
#   u"Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28009E_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009A_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_012MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009I_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009C_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_024M',
#   u'Margin of Error!!Total!!$75,000 or more!!With a broadband Internet subscription'),
#  (u'B28003_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28002_003MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Dial-up with no other type of Internet subscription'),
#  (u'B28004_020M',
#   u'Margin of Error!!Total!!$50,000 to $74,999!!With a broadband Internet subscription'),
#  (u'B28004_020E',
#   u'Estimate!!Total!!$50,000 to $74,999!!With a broadband Internet subscription'),
#  (u'B28009F_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_003M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Dial-up with no other type of Internet subscription'),
#  (u'B28009H_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009H_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_004MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28009A_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009G_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_011M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_011E',
#   u'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_020EA',
#   u'Annotation of Estimate!!Total!!$50,000 to $74,999!!With a broadband Internet subscription'),
#  (u'B28008_006EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!With a cellular data plan'),
#  (u'B28004_025M',
#   u'Margin of Error!!Total!!$75,000 or more!!Without an Internet subscription'),
#  (u'B28005_011EA',
#   u'Annotation of Estimate!!Total!!18 to 64 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009B_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_004E',
#   u'Estimate!!Total!!Less than $10,000!!With a broadband Internet subscription'),
#  (u'B28009B_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009B_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28005_018MA',
#   u'Annotation of Margin of Error!!Total!!65 years and over!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_008MA',
#   u'Annotation of Margin of Error!!Total!!$10,000 to $19,999!!With a broadband Internet subscription'),
#  (u'B28004_003M',
#   u'Margin of Error!!Total!!Less than $10,000!!With dial-up Internet subscription alone'),
#  (u'B28009E_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_013EA',
#   u'Annotation of Estimate!!Total!!$20,000 to $34,999!!Without an Internet subscription'),
#  (u'B28002_008MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28006_017MA',
#   u"Annotation of Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28007_006EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009F_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_008EA', u'Annotation of Estimate!!Total!!No Internet access'),
#  (u'B28002_011M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Other service with no other type of Internet subscription'),
#  (u'B28004_009EA',
#   u'Annotation of Estimate!!Total!!$10,000 to $19,999!!Without an Internet subscription'),
#  (u'B28009G_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_010E',
#   u"Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28007_005MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009D_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009D_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009D_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28003_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_017EA',
#   u'Annotation of Estimate!!Total!!65 years and over!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_011EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Other service with no other type of Internet subscription'),
#  (u'B28009E_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_007M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_007E',
#   u'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!Without an Internet subscription'),
#  (u'B28002_009E',
#   u'Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28011_004E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
#  (u'B28011_004M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
#  (u'B28008_005E',
#   u'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription'),
#  (u'B28008_005M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription'),
#  (u'B28009H_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_019EA',
#   u'Annotation of Estimate!!Total!!$50,000 to $74,999!!With dial-up Internet subscription alone'),
#  (u'B28009A_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28008_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_017EA',
#   u'Annotation of Estimate!!Total!!$35,000 to $49,999!!Without an Internet subscription'),
#  (u'B28009F_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_012EA',
#   u"Annotation of Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!Without an Internet subscription"),
#  (u'B28009I_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009H_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009G_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_006EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Other service'),
#  (u'B28002_004E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_004M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28004_025EA',
#   u'Annotation of Estimate!!Total!!$75,000 or more!!Without an Internet subscription'),
#  (u'B28008_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28006_011EA',
#   u"Annotation of Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28005_006MA',
#   u'Annotation of Margin of Error!!Total!!Under 18 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_004MA',
#   u'Annotation of Margin of Error!!Total!!Less than $10,000!!With a broadband Internet subscription'),
#  (u'B28004_021M',
#   u'Margin of Error!!Total!!$50,000 to $74,999!!Without an Internet subscription'),
#  (u'B28004_021E',
#   u'Estimate!!Total!!$50,000 to $74,999!!Without an Internet subscription'),
#  (u'B28009D_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_005MA',
#   u'Annotation of Margin of Error!!Total!!Under 18 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28003_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28002_005EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Cellular data plan'),
#  (u'B28009D_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009D_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_010E',
#   u'Estimate!!Total!!18 to 64 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_010M',
#   u'Margin of Error!!Total!!18 to 64 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28002_013MA',
#   u'Annotation of Margin of Error!!Total!!No Internet access'),
#  (u'B28006_004EA',
#   u'Annotation of Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009F_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_006EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Cellular data plan!!Cellular data plan with no other type of Internet subscription'),
#  (u'B28009A_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009I_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009I_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_005MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28009B_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009B_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_005M',
#   u'Margin of Error!!Total!!Less than $10,000!!Without an Internet subscription'),
#  (u'B28003_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28003_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_017M',
#   u'Margin of Error!!Total!!65 years and over!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009C_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009C_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_010MA',
#   u"Annotation of Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28005_010MA',
#   u'Annotation of Margin of Error!!Total!!18 to 64 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_007M',
#   u'Margin of Error!!Total!!Internet access without a subscription'),
#  (u'B28004_007EA',
#   u'Annotation of Estimate!!Total!!$10,000 to $19,999!!With dial-up Internet subscription alone'),
#  (u'B28004_012EA',
#   u'Annotation of Estimate!!Total!!$20,000 to $34,999!!With a broadband Internet subscription'),
#  (u'B28009E_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_003EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Dial-up alone'),
#  (u'B28011_002EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription'),
#  (u'B28002_010M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service!!Satellite Internet service with no other type of Internet subscription'),
#  (u'B28009E_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009C_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009I_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009F_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_012E',
#   u'Estimate!!Total!!$20,000 to $34,999!!With a broadband Internet subscription'),
#  (u'B28007_018EA',
#   u'Annotation of Estimate!!Total!!Not in labor force!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009D_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_016EA',
#   u"Annotation of Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28009F_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28008_007EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!Without a cellular data plan'),
#  (u'B28009G_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_007EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_006E',
#   u'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_005M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28011_005E',
#   u'Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28007_018E',
#   u'Estimate!!Total!!Not in labor force!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_018M',
#   u'Margin of Error!!Total!!Not in labor force!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_003MA',
#   u'Annotation of Margin of Error!!Total!!Less than $10,000!!With dial-up Internet subscription alone'),
#  (u'B28002_002EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription'),
#  (u'B28005_016E',
#   u'Estimate!!Total!!65 years and over!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_016M',
#   u'Margin of Error!!Total!!65 years and over!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009B_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_009MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28004_013E',
#   u'Estimate!!Total!!$20,000 to $34,999!!Without an Internet subscription'),
#  (u'B28004_013M',
#   u'Margin of Error!!Total!!$20,000 to $34,999!!Without an Internet subscription'),
#  (u'B28004_016EA',
#   u'Annotation of Estimate!!Total!!$35,000 to $49,999!!With a broadband Internet subscription'),
#  (u'B28002_005M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Cellular data plan'),
#  (u'B28002_005E',
#   u'Estimate!!Total!!With an Internet subscription!!Cellular data plan'),
#  (u'B28002_010MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Satellite Internet service!!Satellite Internet service with no other type of Internet subscription'),
#  (u'B28005_016EA',
#   u'Annotation of Estimate!!Total!!65 years and over!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_013EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_011EA',
#   u'Annotation of Estimate!!Total!!$20,000 to $34,999!!With dial-up Internet subscription alone'),
#  (u'B28006_010EA',
#   u"Annotation of Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28002_007MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28005_004MA',
#   u'Annotation of Margin of Error!!Total!!Under 18 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28008_009E',
#   u'Estimate!!Total!!Has a computer!!Without Internet subscription'),
#  (u'B28008_009M',
#   u'Margin of Error!!Total!!Has a computer!!Without Internet subscription'),
#  (u'B28007_017E',
#   u'Estimate!!Total!!Not in labor force!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_017M',
#   u'Margin of Error!!Total!!Not in labor force!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009D_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28003_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_021EA',
#   u'Annotation of Estimate!!Total!!$50,000 to $74,999!!Without an Internet subscription'),
#  (u'B28009H_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_017EA',
#   u'Annotation of Estimate!!Total!!Not in labor force!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28005_011E',
#   u'Estimate!!Total!!18 to 64 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_011M',
#   u'Margin of Error!!Total!!18 to 64 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_024MA',
#   u'Annotation of Margin of Error!!Total!!$75,000 or more!!With a broadband Internet subscription'),
#  (u'B28009E_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009G_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009I_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009I_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_012EA',
#   u'Annotation of Estimate!!Total!!Internet access without a subscription'),
#  (u'B28002_007EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28009B_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009B_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009F_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009G_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_018EA',
#   u"Annotation of Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!Without an Internet subscription"),
#  (u'B28009C_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009C_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_004M',
#   u'Margin of Error!!Total!!Less than $10,000!!With a broadband Internet subscription'),
#  (u'B28006_006MA',
#   u'Annotation of Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!Without an Internet subscription'),
#  (u'B28005_006E',
#   u'Estimate!!Total!!Under 18 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28005_006M',
#   u'Margin of Error!!Total!!Under 18 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28011_007MA',
#   u'Annotation of Margin of Error!!Total!!Internet access without a subscription'),
#  (u'B28009B_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009C_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_019M',
#   u'Margin of Error!!Total!!$50,000 to $74,999!!With dial-up Internet subscription alone'),
#  (u'B28005_012EA',
#   u'Annotation of Estimate!!Total!!18 to 64 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28009H_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009H_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_006M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_015EA',
#   u'Annotation of Estimate!!Total!!$35,000 to $49,999!!With dial-up Internet subscription alone'),
#  (u'B28007_012E',
#   u'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_012M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009A_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_004EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
#  (u'B28004_023EA',
#   u'Annotation of Estimate!!Total!!$75,000 or more!!With dial-up Internet subscription alone'),
#  (u'B28008_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription'),
#  (u'B28007_019EA',
#   u'Annotation of Estimate!!Total!!Not in labor force!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_005EA',
#   u'Annotation of Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28008_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_019E',
#   u'Estimate!!Total!!Not in labor force!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_019M',
#   u'Margin of Error!!Total!!Not in labor force!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_004E',
#   u'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28006_004M',
#   u'Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009I_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009C_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_003EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Dial-up with no other type of Internet subscription'),
#  (u'B28005_017E',
#   u'Estimate!!Total!!65 years and over!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_011MA',
#   u'Annotation of Margin of Error!!Total!!18 to 64 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009G_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009G_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_012M',
#   u'Margin of Error!!Total!!$20,000 to $34,999!!With a broadband Internet subscription'),
#  (u'B28009E_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28005_018EA',
#   u'Annotation of Estimate!!Total!!65 years and over!!Has a computer!!Without an Internet subscription'),
#  (u'B28002_004EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  (u'B28002_006M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Cellular data plan!!Cellular data plan with no other type of Internet subscription'),
#  (u'B28002_006E',
#   u'Estimate!!Total!!With an Internet subscription!!Cellular data plan!!Cellular data plan with no other type of Internet subscription'),
#  (u'B28009A_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009G_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_013MA',
#   u'Annotation of Margin of Error!!Total!!$20,000 to $34,999!!Without an Internet subscription'),
#  (u'B28004_020MA',
#   u'Annotation of Margin of Error!!Total!!$50,000 to $74,999!!With a broadband Internet subscription'),
#  (u'B28004_005E',
#   u'Estimate!!Total!!Less than $10,000!!Without an Internet subscription'),
#  (u'B28008_006MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!With a cellular data plan'),
#  (u'B28009F_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009F_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_023E',
#   u'Estimate!!Total!!$75,000 or more!!With dial-up Internet subscription alone'),
#  (u'B28004_023M',
#   u'Margin of Error!!Total!!$75,000 or more!!With dial-up Internet subscription alone'),
#  (u'B28003_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28003_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_008MA',
#   u'Annotation of Margin of Error!!Total!!No Internet access'),
#  (u'B28004_008EA',
#   u'Annotation of Estimate!!Total!!$10,000 to $19,999!!With a broadband Internet subscription'),
#  (u'B28008_006E',
#   u'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!With a cellular data plan'),
#  (u'B28002_008EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  (u'B28006_018M',
#   u"Margin of Error!!Total!!Bachelor's degree or higher!!Has a computer!!Without an Internet subscription"),
#  (u'B28006_018E',
#   u"Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!Without an Internet subscription"),
#  (u'B28007_006MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009D_004MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_012M',
#   u'Margin of Error!!Total!!18 to 64 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28002_011MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Other service with no other type of Internet subscription'),
#  (u'B28004_017M',
#   u'Margin of Error!!Total!!$35,000 to $49,999!!Without an Internet subscription'),
#  (u'B28005_017MA',
#   u'Annotation of Margin of Error!!Total!!65 years and over!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009I_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009I_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009G_003E',
#   u'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_003EA',
#   u'Annotation of Estimate!!Total!!Less than $10,000!!With dial-up Internet subscription alone'),
#  (u'B28009E_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28008_009EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without Internet subscription'),
#  (u'B28009G_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009A_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009A_005E',
#   u'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009H_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_019MA',
#   u'Annotation of Margin of Error!!Total!!$50,000 to $74,999!!With dial-up Internet subscription alone'),
#  (u'B28005_005E',
#   u'Estimate!!Total!!Under 18 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_005M',
#   u'Margin of Error!!Total!!Under 18 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_017EA',
#   u"Annotation of Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28006_012MA',
#   u"Annotation of Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!Without an Internet subscription"),
#  (u'B28007_013E',
#   u'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_013M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!Without an Internet subscription'),
#  (u'B28006_011MA',
#   u"Annotation of Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With a broadband Internet subscription"),
#  (u'B28007_013MA',
#   u'Annotation of Margin of Error!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_005E',
#   u'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28009F_005M',
#   u'Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009H_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_017MA',
#   u'Annotation of Margin of Error!!Total!!$35,000 to $49,999!!Without an Internet subscription'),
#  (u'B28004_015E',
#   u'Estimate!!Total!!$35,000 to $49,999!!With dial-up Internet subscription alone'),
#  (u'B28004_015M',
#   u'Margin of Error!!Total!!$35,000 to $49,999!!With dial-up Internet subscription alone'),
#  (u'B28005_012E',
#   u'Estimate!!Total!!18 to 64 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28011_006MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Other service'),
#  (u'B28009B_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28011_002M', u'Margin of Error!!Total!!With an Internet subscription'),
#  (u'B28004_025MA',
#   u'Annotation of Margin of Error!!Total!!$75,000 or more!!Without an Internet subscription'),
#  (u'B28011_007E', u'Estimate!!Total!!Internet access without a subscription'),
#  (u'B28008_003MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28008_009MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without Internet subscription'),
#  (u'B28009E_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28004_025E',
#   u'Estimate!!Total!!$75,000 or more!!Without an Internet subscription'),
#  (u'B28006_005E',
#   u'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28006_005M',
#   u'Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28005_006EA',
#   u'Annotation of Estimate!!Total!!Under 18 years!!Has a computer!!Without an Internet subscription'),
#  (u'B28004_004EA',
#   u'Annotation of Estimate!!Total!!Less than $10,000!!With a broadband Internet subscription'),
#  (u'B28005_018M',
#   u'Margin of Error!!Total!!65 years and over!!Has a computer!!Without an Internet subscription'),
#  (u'B28005_018E',
#   u'Estimate!!Total!!65 years and over!!Has a computer!!Without an Internet subscription'),
#  (u'B28009A_004E',
#   u'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28009A_004M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_013EA', u'Annotation of Estimate!!Total!!No Internet access'),
#  (u'B28006_004MA',
#   u'Annotation of Margin of Error!!Total!!Less than high school graduate or equivalency!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28007_011EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28011_005EA',
#   u'Annotation of Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  (u'B28002_011E',
#   u'Estimate!!Total!!With an Internet subscription!!Other service with no other type of Internet subscription'),
#  (u'B28009D_003EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28002_013M', u'Margin of Error!!Total!!No Internet access'),
#  (u'B28002_013E', u'Estimate!!Total!!No Internet access'),
#  (u'B28005_005EA',
#   u'Annotation of Estimate!!Total!!Under 18 years!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28002_007M',
#   u'Margin of Error!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28002_007E',
#   u'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  (u'B28006_010M',
#   u"Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With dial-up Internet subscription alone"),
#  (u'B28004_017E',
#   u'Estimate!!Total!!$35,000 to $49,999!!Without an Internet subscription'),
#  (u'B28002_005MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Cellular data plan'),
#  (u'B28006_012E',
#   u"Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!Without an Internet subscription"),
#  (u'B28006_012M',
#   u"Margin of Error!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!Without an Internet subscription"),
#  (u'B28004_007MA',
#   u'Annotation of Margin of Error!!Total!!$10,000 to $19,999!!With dial-up Internet subscription alone'),
#  (u'B28009A_003M',
#   u'Margin of Error!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_012MA',
#   u'Annotation of Margin of Error!!Total!!$20,000 to $34,999!!With a broadband Internet subscription'),
#  (u'B28002_006MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription!!Cellular data plan!!Cellular data plan with no other type of Internet subscription'),
#  (u'B28011_002MA',
#   u'Annotation of Margin of Error!!Total!!With an Internet subscription'),
#  (u'B28009A_005MA',
#   u'Annotation of Margin of Error!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28009C_005EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  (u'B28007_005M',
#   u'Margin of Error!!Total!!In the civilian labor force!!Employed!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28002_010E',
#   u'Estimate!!Total!!With an Internet subscription!!Satellite Internet service!!Satellite Internet service with no other type of Internet subscription'),
#  (u'B28011_002E', u'Estimate!!Total!!With an Internet subscription'),
#  (u'B28008_007M',
#   u'Margin of Error!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!Without a cellular data plan'),
#  (u'B28008_007E',
#   u'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!Without a cellular data plan'),
#  (u'B28005_010EA',
#   u'Annotation of Estimate!!Total!!18 to 64 years!!Has a computer!!With dial-up Internet subscription alone'),
#  (u'B28004_024E',
#   u'Estimate!!Total!!$75,000 or more!!With a broadband Internet subscription'),
#  (u'B28009E_004EA',
#   u'Annotation of Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_018MA',
#   u'Annotation of Margin of Error!!Total!!Not in labor force!!Has a computer!!With a broadband Internet subscription'),
#  (u'B28007_005EA',
#   u'Annotation of Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With dial-up Internet subscription alone')]

# %% [markdown]
# Now that you have the variable names use them to extract the relevant data with the ACS API.
#
# The API url is as follows:
#
# root: https://api.census.gov/data/2016/acs/acs1
#
# action: get=\[variable Name\],NAME
#
# geometry: for=\[geometry\]:\[desired geometry values\]in=\[larger geometry\]:\[desired larger geometry values\]
#
# API key: key:\[api key\]
#
# the URL is constructed as root?action&geometry&key
#
# Note that it took me a long time to figure out how to request the right geometry: in the url I write below the geometry is "public%20use%20microdata%20area" where %20 is the character for ' ' (space) in a url, and ":\*" means all PUMAS
#
# state:36 is New York State

# %%
import pandas as pd
import io
from Censuskey import myAPI

# %% [markdown]
# # Getting the broadband access number of households

# %%
url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyNBB +\
",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumaBB = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
#getting the first row of the table: the total number of households

url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyNhouseholds  +\
",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumaPP = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

# %%
pumaPP.head()
# Out:
#    B28002_001E                                               NAME  state  \
# 0        40479                 St. Lawrence County PUMA, New York     36
# 1        67092  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        51614        Warren & Washington Counties PUMA, New York     36
# 3        44300  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        61146  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %% [markdown]
# ## 2.2 generate a feature for the percentage of households with broadband access

# %%
pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
pumaBB["pcBB"]=pumaBB["B28002_004E"]/pumaPP["B28002_001E"]

# %% [markdown]
# ### Checking pcBB makes sense

# %%
pumaBB["pcBB"].head()
# Out:
# 0    0.805529
# 1    0.757333
# 2    0.798427
# 3    0.814334
# 4    0.781507
# Name: pcBB, dtype: float64

# %% [markdown]
# ## 2.3 Now compare it with the AFF published "percentage of households with broadband access" which is a feature available through their website but that cannot be downloaded directly from the API. It compiled by AFF the same way we did above

# %% [markdown]
# Manually you can download the GCT Geographic Comparison Tables. Download the GCT table that contains the percentage of households in each PUMA with broadband internet subscription as follows:
#
# https://factfinder.census.gov/ -> Advanced Search -> Show me all
#
#     - Topics: Product Type -> Geography Comparison Table
#
# select the PERCENT OF HOUSEHOLDS WITH A BROADBAND INTERNET SUBSCRIPTION  at our geography granularity (PUMA) and click Download below. This will generate the table on the fly and you can click again on Download.
#
# Move the file into the PUIdata directory, unzip it and load it with pandas.
#
# Your table shold be labeled as: GCT2801

# %% [markdown]
# One more hurdle: you need to move this data to jupyterhub/compute, and the link is not something you can copy and paste!
# Two solutions:
#
# -easier but less preferible: upload the table you downloaded locally to github AWS, or else where, and download it from compute
#
# -otherwise, learn how to do it with sftp from your local terminal: these are the steps
#
# 1. ON YOUR LOCAL MACHINE where you downloaded the table (which was downloaded as aff_download.zip for me in my ~/Downloads folder) type the following *sftp* command
#
#         fbianco@Federicas-MacBook-Air:~$ sftp fbianco@staging.cusp.nyu.edu
#
# 2. Input your password
#
#         Password:
#         Connected to staging.cusp.nyu.edu.
#
#    This should open an sftp promopt (you should see sftp> at the beginning of the line). Go to the PUI directory (for me /home/fbianco/PUIdata)
#
#         sftp> cd /home/fbianco/PUIdata
#
# 3. Use the sftp command _put_ to copy the file from the local to the remote machine to compute, making sure you use the full path (unless the file was downloaded in your local directory in the local machine)
#
#         sftp> put /Users/fbianco/Downloads/aff_download.zip
#
# You should see:
#
#             Uploading /Users/fbianco/Downloads/aff_download.zip to ....
#
# And the file can be unzipped and read into your code with pandas. I leave the read in line below for your convenience, those are the only variables you need.

# %% [markdown]
# # Here we read the Census data

# %%
bbpc= pd.read_csv(PUIdata+"/ACS_16_1YR_GCT2801.ST50_with_ann.csv",usecols=["Target Geo Id2","Percent","Margin of Error"],skiprows=[0])
bbpc.head()

del pumaBB["Unnamed: 4"] #we erase unnecesary columns
pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area      pcBB
# 0                        100  0.805529
# 1                        200  0.757333
# 2                        300  0.798427
# 3                        401  0.814334
# 4                        402  0.781507

# %% [markdown]
# notice 2 things:
#     - that the Target Geo Id2: GCT_STUB.target-geo-id2 is a 7 digits number. See my comment above about it.
#     - that there is a weird double header. You can deal with it in one of 2 ways: either reread the file in skipping one row and using the second row as header, or remove that row (for example with bbpc.drop(0, inplace=True)) but also then you should check the *type* of your GCT_STUB.target-geo-id2 feature! The fact that pandas had to read in a column with nombers and characters forced it to read it as a string, and you need to convert it (.astype(int)) to merge it easily with the API acquired data.
#
# In the API dataframe the PUMA id was a 4 digit number. If you have them both as integers and you remove the initial three digits (for example by subtracting 360000 from each value wich you can do as bbpc["gid"] = bbpc.gid - 3600000 then you can merge on the puma id

# %%
print (type(bbpc["Target Geo Id2"][2]))
print (type(pumaBB["public use microdata area"][2]))
# Out:
# <type 'numpy.int64'>
# <type 'numpy.int64'>

# %% [markdown]
# # Here we munge the data to get it to look as we need

# %%
bbpc.columns=["gid","Percent","error"]

# %%
pumaBB.columns=[u'B28002_004E', u'NAME', u'state', u'gid',u'pcBB']

# %%
bbpc["gid"]=bbpc["gid"]-3600000

# %%
diff_=pd.merge(pumaBB,bbpc,on="gid")[["pcBB", "Percent"]]

# %%
diff_.head()
# Out:
#        pcBB  Percent
# 0  0.805529     80.6
# 1  0.757333     75.7
# 2  0.798427     79.8
# 3  0.814334     81.4
# 4  0.781507     78.2

# %% [markdown]
# ## check that the percentage of households with broadband you generated and the one you red in from the table you downloaded manually are the same

# %%
diff_["diff"] = np.abs(diff_["pcBB"] - (diff_["Percent"]/100.0).astype(float))

diff_.describe()
# Out:
#              pcBB     Percent        diff
# count  145.000000  145.000000  145.000000
# mean     0.818455   81.843448    0.000262
# std      0.070634    7.065358    0.000145
# min      0.549329   54.900000    0.000002
# 25%      0.777703   77.800000    0.000123
# 50%      0.828261   82.800000    0.000272
# 75%      0.873051   87.300000    0.000391
# max      0.934041   93.400000    0.000499

# %% [markdown]
# the maximum difference should only be a few percent
#
# It is only of by a few percent

# %% [markdown]
# # 3 Plot a choropleth of NYC broadband access
# ## 3.1 Merge with the puma geodataframe and plot a choropleth of the percentage of households with broadband access

# %%
print (type(df.puma[1]))
# Out:
# <type 'unicode'>

# %% [markdown]
# # Again make the data look like we need to

# %%
df.puma=df.puma.apply(int)
df = df.merge(bbpc,left_on="puma",right_on="gid")
df.head()
# Out:
#    puma     shape_leng    shape_area  \
# 0  3701   53227.144376  9.792852e+07
# 1  3702  106050.008344  1.889860e+08
# 2  3703  304875.033427  2.670770e+08
# 3  3704   47970.900868  1.062129e+08
# 4  3705   68593.066759  1.224946e+08
#
#                                             geometry   gid  Percent  error
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  3701     84.3    2.6
# 1  POLYGON ((-73.86477258283533 40.90201244187379...  3702     68.3    3.7
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  3703     82.8    3.2
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  3704     72.6    3.6
# 4  POLYGON ((-73.87045508990893 40.86663286876232...  3705     69.4    3.2

# %%
cp.choroplethNYC(df, column="Percent", color="k",cmap="viridis", edgecolor="k", lw=0.5);

# %% [markdown]
# # Fig 2. We can see in the previous map how the different areas in NYC have different access to Broadband internet. Not sure why, but the lower east looks like an outlier.

# %% [markdown]
# # 4. LinkNYC: assess whether the locations of the linkNYC stations are supplying internet where it is needed.
#
# acquire the linkNYC locations and prepare them into a dataframe
# read it in from the HW9_fb55 folder in :
# https://github.com/fedhere/PUI2017_fb55
#
# Notice that you can also get a linkNYC locations shapefile from NYC open data, as I did to generate this, but I want you do to do some extra coordinates gymnastics for practice so use the one I provide.

# %% [markdown]
# # Access Link NYC data through Federicas github

# %%
linkNYC = pd.read_csv("https://raw.githubusercontent.com/fedhere/PUI2017_fb55/master/HW9_fb55/linkNYClocations.csv")

# %%
linkNYC.head()
# Out:
#    Unnamed: 0     link_site  longitude  date_link_   latitude
# 0           0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1           1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2           2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3           3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4           4  bk-01-125268 -73.953439  2017-03-31  40.728133

# %%
linkNYC.shape
# Out:
# (1414, 5)

# %% [markdown]
# ## combine long lat into a column like you did in the lab to greate a "geometry" column for the dataframe, then convert the dataframe into a GeoDataFrame _linkNYC_ and set native coordinates  frame to lat/lon as you did in the lab

# %%
from fiona.crs import from_epsg
import shapely

# %% [markdown]
# # Doing as the instructions says, making native coordinates lat long numbers

# %%
linkNYC['lonlat']=zip(linkNYC.longitude,linkNYC.latitude)
linkNYC['geometry']=linkNYC[['lonlat']].applymap(lambda x:shapely.geometry.Point(x))

# %%
linkNYC_ = gp.GeoDataFrame(linkNYC)
linkNYC_.crs = from_epsg(4326)
linkNYC_.head()
# Out:
#    Unnamed: 0     link_site  longitude  date_link_   latitude  \
# 0           0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1           1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2           2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3           3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4           4  bk-01-125268 -73.953439  2017-03-31  40.728133
#
#                             lonlat                                  geometry
# 0      (-73.94248859, 40.70166753)          POINT (-73.94248859 40.70166753)
# 1  (-73.9421692831, 40.7015421938)      POINT (-73.9421692831 40.7015421938)
# 2  (-73.9422392385, 40.7019303439)  POINT (-73.94223923850001 40.7019303439)
# 3      (-73.94291758, 40.70506042)          POINT (-73.94291758 40.70506042)
# 4          (-73.953439, 40.728133)              POINT (-73.953439 40.728133)

# %%
import matplotlib as mpl
mpl.rcParams['lines.markersize'] = 2.5

# %% [markdown]
# # plot the location of the linkNYC stations on top of a choropleth of broadband access percentage in *5 equal intervals*
#
# I have also color coded the station by how long ago they have been installed, using the date datetime variable

# %%
data,date_link_,figure = cp.choroplethNYC(df, column="Percent", color="k",cmap="winter", edgecolor="k", scheme='equal_interval',k=5,lw=1)
cp.choroplethNYC(linkNYC_,ax=date_link_,cmap="autumn");
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Fig 3. The previous map shows the Link NYC points plotted on top of the NYC map divided by puma colored by the  Broadband access. It looks like there are more NYC link points on top of the PUMA sections with more access to Broadband. Which raises the question, is there a correlation or ar the Link NYC points being installed where they are less needed?

# %% [markdown]
# # 5 Find the number of linkNYC locations per person by PUMA
#
# ## 5.1 with the AFF API from ACS get the total population by puma and merge it into your GeoDF

# %% [markdown]
# the ACS population by  variable is B00001_001E, and of course your geometry is PUMA, _public%20use%20microdata%20area:*_, as before

# %% [markdown]
# # Following the instruction we get the population by PUMA

# %%
keyPop = "B00001_001E"
aff1y['variables'][keyPop]
# Out:
# {u'attributes': u'B00001_001EA',
#  u'concept': u'UNWEIGHTED SAMPLE COUNT OF THE POPULATION',
#  u'group': u'B00001',
#  u'label': u'Estimate!!Total',
#  u'limit': 0,
#  u'predicateType': u'int',
#  u'validValues': []}

# %%
url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyPop +\
",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumaPop = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

# %%
pumaPop.head()
# Out:
#    B00001_001E                                               NAME  state  \
# 0         3075                 St. Lawrence County PUMA, New York     36
# 1         4356  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2         2736        Warren & Washington Counties PUMA, New York     36
# 3         2722  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4         2874  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
pumaPop=pumaPop[["B00001_001E","public use microdata area"]]
pumaPop.columns=["population","gid"]

# %% [markdown]
# # We merge the datasets to start working

# %%
df = df.merge(pumaPop,left_on="gid",right_on="gid")

# %%
df.head()
# Out:
#    puma     shape_leng    shape_area  \
# 0  3701   53227.144376  9.792852e+07
# 1  3702  106050.008344  1.889860e+08
# 2  3703  304875.033427  2.670770e+08
# 3  3704   47970.900868  1.062129e+08
# 4  3705   68593.066759  1.224946e+08
#
#                                             geometry   gid  Percent  error  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  3701     84.3    2.6
# 1  POLYGON ((-73.86477258283533 40.90201244187379...  3702     68.3    3.7
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  3703     82.8    3.2
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  3704     72.6    3.6
# 4  POLYGON ((-73.87045508990893 40.86663286876232...  3705     69.4    3.2
#
#    population
# 0        1517
# 1        1959
# 2        1305
# 3        1882
# 4        2011

# %% [markdown]
# ## 5.2 find the number of station per 100 people per PUMA
# **Important** you can do this with an sjoin(). But sjoin() should not be used with lat/lon coordinates cause they are **not "flat coordinates"**. Since spattial joins are done in cartesian geometry the only coordinate systems suitable to spatial joins are flat coordinate plane systems, which in the NYC area is 2263. So before you proceed to the sjoin you have to convert both pumashp and linkNYC to 2263 (for example with GeoDataFrame method .to_crs(epsg=...) )
#
#
# (A note: You can also do this by hand by asking for each point if it is in any of the regions, for example in a for loop. But that is escruciatingly slow, unless you get smart about your requests (for example for a given PUMA not asking if the coordinates of a point are very different from the center of a PUMA). With the new version of geopandas this is not needed, cause the sjoin is fast, but with the older versions this was sometimes better) )

# %% [markdown]
# # As stated in the instructions we make the coordinates look like they should

# %%
linkNYC_ = gp.GeoDataFrame(linkNYC)
linkNYC_.crs = from_epsg(2263)

# %%
df = gp.GeoDataFrame(df)
df.crs = from_epsg(2263)

# %% [markdown]
# convert coordinates for pumashp and linkNYC

# %% [markdown]
# create a geodataframe with a spatial join and use groupby to count the number of linkNYC in each PUMA

# %%
df.shape
# Out:
# (55, 8)

# %%
linkNYC_.shape
# Out:
# (1414, 7)

# %%
df.head()
# Out:
#    puma     shape_leng    shape_area  \
# 0  3701   53227.144376  9.792852e+07
# 1  3702  106050.008344  1.889860e+08
# 2  3703  304875.033427  2.670770e+08
# 3  3704   47970.900868  1.062129e+08
# 4  3705   68593.066759  1.224946e+08
#
#                                             geometry   gid  Percent  error  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  3701     84.3    2.6
# 1  POLYGON ((-73.86477258283533 40.90201244187379...  3702     68.3    3.7
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  3703     82.8    3.2
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  3704     72.6    3.6
# 4  POLYGON ((-73.87045508990893 40.86663286876232...  3705     69.4    3.2
#
#    population
# 0        1517
# 1        1959
# 2        1305
# 3        1882
# 4        2011

# %%
linkNYC_.head()
# Out:
#    Unnamed: 0     link_site  longitude  date_link_   latitude  \
# 0           0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1           1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2           2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3           3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4           4  bk-01-125268 -73.953439  2017-03-31  40.728133
#
#                             lonlat                                  geometry
# 0      (-73.94248859, 40.70166753)          POINT (-73.94248859 40.70166753)
# 1  (-73.9421692831, 40.7015421938)      POINT (-73.9421692831 40.7015421938)
# 2  (-73.9422392385, 40.7019303439)  POINT (-73.94223923850001 40.7019303439)
# 3      (-73.94291758, 40.70506042)          POINT (-73.94291758 40.70506042)
# 4          (-73.953439, 40.728133)              POINT (-73.953439 40.728133)

# %% [markdown]
# # Making the count  using the Geo Pandas sjoin

# %%
linkpp = gp.sjoin(df,linkNYC_, how="left").groupby("gid").count() 

linkpp.head()
# Out:
#       puma  shape_leng  shape_area  geometry  Percent  error  population  \
# gid
# 3701     1           1           1         1        1      1           1
# 3702     1           1           1         1        1      1           1
# 3703     1           1           1         1        1      1           1
# 3704     1           1           1         1        1      1           1
# 3705     1           1           1         1        1      1           1
#
#       index_right  Unnamed: 0  link_site  longitude  date_link_  latitude  \
# gid
# 3701            1           1          1          1           1         1
# 3702            0           0          0          0           0         0
# 3703            0           0          0          0           0         0
# 3704            0           0          0          0           0         0
# 3705            1           1          1          1           1         1
#
#       lonlat
# gid
# 3701       1
# 3702       0
# 3703       0
# 3704       0
# 3705       1

# %% [markdown]
# finally merge back into the pumashp. Make sure you use the correct scheme for merging: you want to have _all_ the PUMAs, not only the ones that have linkNYC in them in the final geoDF

# %%
linkpp_=linkpp["puma"].reset_index()
linkpp_.columns=["gid","count_link"]

# %% [markdown]
# # Here we make the merge

# %%
pumashplc = df.merge(linkpp_,left_on="gid",right_on="gid")
pumashplc.head()
# Out:
#    puma     shape_leng    shape_area  \
# 0  3701   53227.144376  9.792852e+07
# 1  3702  106050.008344  1.889860e+08
# 2  3703  304875.033427  2.670770e+08
# 3  3704   47970.900868  1.062129e+08
# 4  3705   68593.066759  1.224946e+08
#
#                                             geometry   gid  Percent  error  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  3701     84.3    2.6
# 1  POLYGON ((-73.86477258283533 40.90201244187379...  3702     68.3    3.7
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  3703     82.8    3.2
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  3704     72.6    3.6
# 4  POLYGON ((-73.87045508990893 40.86663286876232...  3705     69.4    3.2
#
#    population  count_link
# 0        1517           1
# 1        1959           1
# 2        1305           1
# 3        1882           1
# 4        2011           1

# %%
pumashplc["linkNYCp100p"]=100*pumashplc.count_link/pumashplc.population

# %%
#linkNYC per 100 inhabitants
pumashplc["linkNYCp100p"].describe()
# Out:
# count    55.000000
# mean      1.580066
# std       2.925439
# min       0.024994
# 25%       0.050386
# 50%       0.538358
# 75%       1.646966
# max      15.141540
# Name: linkNYCp100p, dtype: float64

# %% [markdown]
# # at last, plot the linkNYC locations on top of a choropleth of number of stations per 100 people  in 10 equal intervals

# %%
data,axis,figure=cp.choroplethNYC(pumashplc, column="linkNYCp100p", color="red",cmap="winter", edgecolor="black", scheme='equal_interval',k=10,lw=1)
cp.choroplethNYC(linkNYC_,ax=axis,cmap="autumn");

# %% [markdown]
# # Figure 4. Firstly we can see that dividing in 10 equal intervals (number of stations per 100 people) might not be the best idea, because we cannot see differences in many of the PUMA divisions. Secondly we can see that there are a couple PUMA divisions that definitively have a much higher amount of stations per 100 people, nevertheless these locations are close to middtown, where you have a lot of offices, but not a lot of housing, so probably during the day you will have a lot of people around, that are not included in the census because they do not live there.

# %% [markdown]
# # Extra credit 1:
# How would you enhance the visibility of this map? you are working with numbers that are mostly very low, and reside near each other, and them have a few much higher value points. Notice that here the high values are interesting though and should not be thrown away!

# %%
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['figure', 'axis']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
pl.hist(pumashplc["count_link"], bins=30);

# %% [markdown]
# # Figure 5. Histogram of number of link spots by puma.

# %%
algo,eje,figurita=cp.choroplethNYC(pumashplc, column="linkNYCp100p", color="white",cmap="winter", edgecolor="black", scheme='quantiles',k=10,lw=1)
cp.choroplethNYC(linkNYC_,ax=eje,cmap="autumn");

# %% [markdown]
# # Fig 6. It looks like using quantiles instead of equal partisions make more sense and provide better visualization.  Nevertheless the analysis remains similar to the previous map.

# %% [markdown]
# ## Extra Credit 2:
# plot Spatial Lag Deciles that describe the impact of linkNYC in providing access where needed. You can follow what you did in the lab, but you need to create a metric based on the data you have tha measures the impact of linkNYC

# %% [markdown]
# this is whay I came up with, and needs not be the same for you. But properly describe what you obtain

# %% [markdown]
# Note: To find the table you extracted through the API manually you could
#
# https://factfinder.census.gov/ -> Advanced Search -> Show me all
#
#     - Topics: Housing -> Physical Characteristics -> Internet Access
#     - Geographies -> all geography types -> Public Use Microdata Areas (755)
#                      -> Select a State: New York -> All Pubic Use Microdaa Areas within New York
#                      -> Add Your Selection
#     - Years -> 2016
